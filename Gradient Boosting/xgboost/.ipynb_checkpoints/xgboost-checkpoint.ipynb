# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
import xgboost as xgb

# %%
df = pd.read_csv("./data_treated.csv")
df_test = pd.read_csv("./data_treated_final.csv")
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       41    4        2          2        0   4522.0        0     0        0
# 1       42    1        1          0        1    398.0        1     0        2
# 2       26    8        2          1        0    706.0        0     0        2
# 3       54    4        1          2        0      0.0        0     1        0
# 4       43    6        1          1        0    918.0        1     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 37843   43    4        1          2        0  13851.0        1     0        0
# 37844   34    1        1          0        0    357.0        1     0        2
# 37845   30    4        2          2        0   4889.0        0     0        0
# 37846   40    6        1          2        0    271.0        1     0        0
# 37847   60    3        1          2        0    443.0        0     0        2
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0       28      1        55         1     -1         0         3  0
# 1       16      8       251         4     -1         0         3  0
# 2        8     10       118         1    105         2         1  0
# 3       19      9       307         3     -1         0         3  0
# 4        6      8       193         1     -1         0         3  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 37843   21      9       259         1     -1         0         3  0
# 37844   14      8       197         2     -1         0         3  0
# 37845   11      1       545         2     -1         0         3  1
# 37846   21      9       124         3    102         4         0  0
# 37847    5      6        60         1     -1         0         3  0
#
# [37848 rows x 17 columns]

# %%
df_test
# Out:
#       age  job  marital  education  default      balance  housing  loan  \
# 0      26    6        2          2        0  -101.000000        0     1
# 1      47    9        1          1        0  1167.000000        1     0
# 2      35    6        1          2        0  2427.000000        0     0
# 3      54    9        0          1        0  1381.651088        0     0
# 4      27    1        2          1        0  -208.000000        1     0
# ...   ...  ...      ...        ...      ...          ...      ...   ...
# 5206   38    0        1          1        0  1767.000000        1     0
# 5207   39    3        1          0        0   562.000000        0     0
# 5208   46    9        1          1        0     0.000000        0     0
# 5209   41    9        2          1        0  1195.000000        1     0
# 5210   56    1        1          1        0  1381.651088        1     0
#
#       contact  day  month  duration  campaign  pdays  previous  poutcome
# 0           0   29      4       172         1     -1         0         3
# 1           0    2      3       139         3     73         2         2
# 2           0   12      5       210         3    158         7         1
# 3           0   30      4        86         1     -1         0         3
# 4           2   21      8       127         2     -1         0         3
# ...       ...  ...    ...       ...       ...    ...       ...       ...
# 5206        0   12      9       893         7     -1         0         3
# 5207        0   12      1       234         2     -1         0         3
# 5208        2   20      6       625         1     -1         0         3
# 5209        0   19      9       187         6    188         9         0
# 5210        2    7      8       139         1     -1         0         3
#
# [5211 rows x 16 columns]

# %%
X = df.drop('y', axis = 1)
y = df['y']
#from sklearn.preprocessing import StandardScaler 
from imblearn.over_sampling import SMOTE
smote = SMOTE()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
X_train, y_train = X_resampled, y_resampled

# %%
models = []
y_preds = []
learning_rates = []
for i in range(100, 10001, 100):
    model = xgb.XGBClassifier(learning_rate=i/10000, seed=1234, objective='binary:logistic', booster="dart")
    model.fit(X_train, y_train)
    models.append(model)
    y_preds.append(model.predict(X_test))
    learning_rates.append(i/10000)

print("Max_recall: ", max([metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))]), "at learning rate: ", learning_rates[[metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))].index(max([metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))]))], "accuracy: ", metrics.accuracy_score(y_test, y_preds[[metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))].index(max([metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))]))]), "precision: ", metrics.precision_score(y_test, y_preds[[metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))].index(max([metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))]))]), "i = ", [metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))].index(max([metrics.recall_score(y_test, y_preds[i]) for i in range(len(models))])))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 6
#       4 for i in range(100, 10001, 100):
#       5     model = xgb.XGBClassifier(learning_rate=i/10000, seed=1234, objective='binary:logistic', booster="dart")
# ----> 6     model.fit(X_train, y_train)
#       7     models.append(model)
#       8     y_preds.append(model.predict(X_test))
#
# File c:\Users\artda\Miniconda3\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\artda\Miniconda3\Lib\site-packages\xgboost\sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File c:\Users\artda\Miniconda3\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\artda\Miniconda3\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\artda\Miniconda3\Lib\site-packages\xgboost\core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
y_pred = models[1].predict(df_test)
df_resultado = pd.read_csv("./bank_test.csv")

# %%
df_resultado = pd.DataFrame({'id': np.array(df_resultado['id']), "y": y_pred})
df_resultado.index = df_resultado["id"]
df_resultado = df_resultado.drop('id',axis=1)

# %%
df_resultado.to_csv("./_target.csv")
